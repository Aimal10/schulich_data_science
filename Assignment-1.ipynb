# %% [markdown]
# Assignment Submitted by- Aimal Dastagirzada

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data.csv')

# %%
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date
# 2    Product_46   Region_3   20.43        12.0  2022-01-03
# 3    Product_36   Region_1   12.77        10.0  2022-01-04
# 4    Product_17   Region_6  125.69         6.0  2022-01-05
# 5    Product_45   Region_1    8.63        11.0  2022-01-06
# 6    Product_31   Region_3   23.73         6.0  2022-01-07
# ..          ...        ...     ...         ...         ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15
# 993   Product_7   Region_9  128.51        17.0  2024-09-20
# 994   Product_1   Region_4   95.24         7.0  2024-09-21
# 998   Product_2  Region_10   43.44        15.0  2024-09-25
# 999  Product_35   Region_8   56.95         6.0  2024-09-26
#
# [797 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797 entries, 2 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     797 non-null    object
#  1   Region      797 non-null    object
#  2   Price       712 non-null    float64
#  3   Units Sold  721 non-null    float64
#  4   Sale Date   797 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 37.4+ KB

# %%
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   945.000000  946.000000        1050
# unique          50        10          NaN         NaN        1000
# top     Product_45  Region_9          NaN         NaN  2022-07-28
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.598688   10.048626         NaN
# std            NaN       NaN   124.020322    3.172261         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.430000    8.000000         NaN
# 50%            NaN       NaN    78.130000   10.000000         NaN
# 75%            NaN       NaN   142.570000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df.head(10)
# Out:
#       Product    Region   Price  Units Sold   Sale Date
# 0         NaN  Region_6   75.96        10.0  2022-01-01
# 1         NaN  Region_1  175.78         8.0  2022-01-02
# 2  Product_46  Region_3   20.43        12.0  2022-01-03
# 3  Product_36  Region_1   12.77        10.0  2022-01-04
# 4  Product_17  Region_6  125.69         6.0  2022-01-05
# 5  Product_45  Region_1    8.63        11.0  2022-01-06
# 6  Product_31  Region_3   23.73         6.0  2022-01-07
# 7  Product_18  Region_7   19.27         9.0  2022-01-08
# 8  Product_16  Region_9   30.70        14.0  2022-01-09
# 9   Product_9  Region_2  264.05         7.0  2022-01-10

# %%
df.tail(5)
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 1045  Product_45  Region_7   78.69         8.0  2022-07-28
# 1046   Product_1  Region_6     NaN         8.0  2022-08-02
# 1047  Product_17  Region_2  114.37        11.0  2023-12-18
# 1048         NaN  Region_8     NaN         5.0  2023-12-27
# 1049  Product_16  Region_2   69.30         8.0  2024-02-23

# %%
df[df['Units Sold'].isnull()]
# Out:
#          Product     Region   Price  Units Sold   Sale Date
# 16    Product_43   Region_6   68.53         NaN  2022-01-17
# 62     Product_5  Region_10   71.01         NaN  2022-03-04
# 81    Product_23   Region_5    9.93         NaN  2022-03-23
# 86     Product_5   Region_6   44.88         NaN  2022-03-28
# 93    Product_29   Region_6   87.63         NaN  2022-04-04
# ...          ...        ...     ...         ...         ...
# 990          NaN   Region_2     NaN         NaN  2024-09-17
# 1005  Product_15        NaN   59.91         NaN  2022-05-17
# 1012  Product_40   Region_8   92.70         NaN  2023-05-17
# 1013  Product_22   Region_9  141.53         NaN  2022-05-26
# 1040  Product_44   Region_9  101.69         NaN  2024-09-11
#
# [104 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)
#Dropping the duplicate values

# %%
df['Product'].isnull().sum()
#To see the sum of empty data in product column
# Out:
# 100

# %%
df.dropna(subset= ['Product' ,'Region'] , inplace=True)
# Since there was no relation between the Product, Region and price. So filling up empty product would not be possible hence I chose to drop all the empty cells in two colums

# %%
df_grouped = df.groupby('Product')
#Goruping by Product

# %%
df_grouped.groups
#Goruping by Groups
# Out:
# {'Product_1': [11, 13, 15, 34, 88, 140, 213, 265, 312, 393, 407, 467, 563, 609, 711, 848, 931, 964, 994], 'Product_10': [47, 84, 220, 253, 294, 375, 397, 449, 599, 643, 673, 754, 895, 934], 'Product_11': [26, 70, 256, 361, 371, 391, 455, 809, 868, 971], 'Product_12': [59, 172, 173, 245, 311, 521, 536, 576, 627, 801, 882], 'Product_13': [25, 35, 49, 94, 113, 156, 204, 237, 295, 326, 343, 364, 389, 403, 522, 621, 676, 720, 746, 752, 807, 892, 954, 962], 'Product_14': [22, 230, 232, 264, 351, 468, 473, 546, 574, 651, 672, 832, 845, 889, 978], 'Product_15': [92, 217, 286, 356, 510, 552, 588, 595, 667, 745, 780, 834, 849, 924, 958, 969, 980], 'Product_16': [8, 146, 153, 180, 275, 466, 491, 505, 547, 674, 721, 735, 783, 796, 819, 914, 916, 930], 'Product_17': [4, 17, 51, 71, 72, 122, 148, 192, 227, 267, 313, 533, 614, 624, 712, 716, 739, 741], 'Product_18': [7, 65, 67, 249, 252, 254, 316, 376, 383, 502, 523, 899, 942], 'Product_19': [212, 244, 258, 269, 352, 378, 433, 496, 512, 528, 589, 6
# ...

# %%
df_grouped.get_group('Product_1')
#To get the group by product so we can see in each product list how many data entries are missing
# Out:
#        Product     Region   Price  Units Sold   Sale Date
# 11   Product_1   Region_4   63.04         9.0  2022-01-12
# 13   Product_1   Region_4   10.15         8.0  2022-01-14
# 15   Product_1   Region_2   46.23        11.0  2022-01-16
# 34   Product_1   Region_9   47.90        11.0  2022-02-04
# 88   Product_1   Region_2   85.46        10.0  2022-03-30
# 140  Product_1   Region_4   28.61         9.0  2022-05-21
# 213  Product_1   Region_6     NaN         8.0  2022-08-02
# 265  Product_1   Region_1  158.05         8.0  2022-09-23
# 312  Product_1   Region_3     NaN        10.0  2022-11-09
# 393  Product_1   Region_6   64.53        10.0  2023-01-29
# 407  Product_1   Region_5   78.94        16.0  2023-02-12
# 467  Product_1  Region_10   88.44         8.0  2023-04-13
# 563  Product_1   Region_1   51.91        16.0  2023-07-18
# 609  Product_1   Region_1   36.67         9.0  2023-09-02
# 711  Product_1   Region_3  268.73         8.0  2023-12-13
# ...

# %%
df[(df['Product'] == 'Product_1') & (df['Region'] == 'Region_1')]
# Out:
#        Product    Region   Price  Units Sold   Sale Date
# 265  Product_1  Region_1  158.05         8.0  2022-09-23
# 563  Product_1  Region_1   51.91        16.0  2023-07-18
# 609  Product_1  Region_1   36.67         9.0  2023-09-02
# 964  Product_1  Region_1   71.79         9.0  2024-08-22

# %%
import seaborn as sns

# %%
sns.scatterplot(x ='Product' , y='Price' ,data=df)
#to get a visual effect of the data values for outlier analysis
# Out:
# <Axes: xlabel='Product', ylabel='Price'>

# %%
df[(df['Price'] >= 1500)]
#Finding the axis of the price above 1500
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 969  Product_15  Region_8  2143.3         5.0  2024-08-27

# %%
df.drop(969, axis=0)
#Dropping the outlier using the index values
# Out:
#         Product     Region   Price  Units Sold   Sale Date
# 2    Product_46   Region_3   20.43        12.0  2022-01-03
# 3    Product_36   Region_1   12.77        10.0  2022-01-04
# 4    Product_17   Region_6  125.69         6.0  2022-01-05
# 5    Product_45   Region_1    8.63        11.0  2022-01-06
# 6    Product_31   Region_3   23.73         6.0  2022-01-07
# ..          ...        ...     ...         ...         ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15
# 993   Product_7   Region_9  128.51        17.0  2024-09-20
# 994   Product_1   Region_4   95.24         7.0  2024-09-21
# 998   Product_2  Region_10   43.44        15.0  2024-09-25
# 999  Product_35   Region_8   56.95         6.0  2024-09-26
#
# [809 rows x 5 columns]

# %%
df[(df['Price'] >= 1500)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 969  Product_15  Region_8  2143.3         5.0  2024-08-27

# %%
df.drop(969, axis= 0, inplace=True)
#Dropping the outlier using the index values

# %%
sns.scatterplot(x='Region' , y='Price' ,data=df)
#To see the effect of outlier
# Out:
# <Axes: xlabel='Region', ylabel='Price'>

# %%
df[(df['Region'] == 'Region_3') & (df['Price'] > 600)]
# Finding the outlier
# Out:
#         Product    Region  Price  Units Sold   Sale Date
# 728  Product_31  Region_3  665.0         9.0  2023-12-30

# %%
df.to_csv('Outlier_Analysis.csv')
#saved a copy of data cleaning as a quick checkpoint

# %%
df.drop(728, inplace=True)
# removed the outlier

# %%
sns.scatterplot(x='Region', y='Price', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Price'>

# %%
df[(df['Region'] == 'Region_2') & (df['Price'] > 500)]
#outliers for group 1
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 189  Product_35  Region_1  511.74        10.0  2022-07-09
# 853  Product_41  Region_1  713.29        10.0  2024-05-03

# %%
df.drop(189, inplace=True)
df.drop(853 , inplace=True)

# %%
df[(df['Region'] == 'Region_6') & (df['Price'] > 500)]
#Drop outlier for group 3
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 834  Product_15  Region_6  510.06        10.0  2024-04-14

# %%
df.drop(834, inplace=True)
#Drop 834 outlier

# %%
df[(df['Region'] == 'Region_7') & (df['Price'] > 500)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 264  Product_14  Region_7  517.29        10.0  2022-09-22

# %%
df.drop(264, inplace=True)
#Dropping the outlier using the index values

# %%
df[(df['Region'] == 'Region_9') & (df['Price'] > 450)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 234  Product_34  Region_9  496.61         8.0  2022-08-23

# %%
df.drop(234,inplace=True)
#Dropping the outlier using the index values

# %%
df[(df['Region'] == 'Region_2') & (df['Price'] > 500)]
# Out:
#         Product    Region  Price  Units Sold   Sale Date
# 814  Product_26  Region_2  623.6        12.0  2024-03-25

# %%
df.drop(814, inplace=True )

# %%
sns.scatterplot(x='Region', y= 'Price' ,data=df)
# To see the scatter plot which wether there is still outliers
# Out:
# <Axes: xlabel='Region', ylabel='Price'>

# %%
df[(df['Region'] == 'Region_6') & (df['Price'] > 400)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 500  Product_40  Region_6  426.02         NaN  2023-05-16

# %%
df.drop(500, inplace=True)

# %%
df[(df['Region'] == 'Region_8') & (df['Price'] > 500)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 437  Product_26  Region_8  585.17        13.0  2023-03-14
# 684  Product_45  Region_8  580.60         NaN  2023-11-16

# %%
df.drop(437, inplace=True)
#Dropping the outlier using the index values

# %%
df.drop(684, inplace=True)
#Dropping the outlier using the index values

# %%
df[(df['Region'] == 'Region_2') & (df['Price'] > 450)]
# Out:
#         Product    Region  Price  Units Sold   Sale Date
# 293  Product_22  Region_2  493.2         NaN  2022-10-21

# %%
df.drop(293, inplace=True)
#Dropping the outlier using the index values

# %%
df[(df['Region'] == 'Region_4') & (df['Price'] > 450)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date
# 526  Product_31  Region_4  505.01        11.0  2023-06-11

# %%
df.drop(526, inplace=True)
#Dropped value

# %%
df_grouped = df.groupby('Product')

# %%
df_grouped.groups
# Out:
# {'Product_1': [11, 13, 15, 34, 88, 140, 213, 265, 312, 393, 407, 467, 563, 609, 711, 848, 931, 964, 994], 'Product_10': [47, 84, 220, 253, 294, 375, 397, 449, 599, 643, 673, 754, 895, 934], 'Product_11': [26, 70, 256, 361, 371, 391, 455, 809, 868, 971], 'Product_12': [59, 172, 173, 245, 311, 521, 536, 576, 627, 801, 882], 'Product_13': [25, 35, 49, 94, 113, 156, 204, 237, 295, 326, 343, 364, 389, 403, 522, 621, 676, 720, 746, 752, 807, 892, 954, 962], 'Product_14': [22, 230, 232, 351, 468, 473, 546, 574, 651, 672, 832, 845, 889, 978], 'Product_15': [92, 217, 286, 356, 510, 552, 588, 595, 667, 745, 780, 849, 924, 958, 980], 'Product_16': [8, 146, 153, 180, 275, 466, 491, 505, 547, 674, 721, 735, 783, 796, 819, 914, 916, 930], 'Product_17': [4, 17, 51, 71, 72, 122, 148, 192, 227, 267, 313, 533, 614, 624, 712, 716, 739, 741], 'Product_18': [7, 65, 67, 249, 252, 254, 316, 376, 383, 502, 523, 899, 942], 'Product_19': [212, 244, 258, 269, 352, 378, 433, 496, 512, 528, 589, 600, 607, 611, 6
# ...

# %%
df_grouped.get_group('Product_1')
#Grouping the product by product_Number i.e Product_1
# Out:
#        Product     Region   Price  Units Sold   Sale Date
# 11   Product_1   Region_4   63.04         9.0  2022-01-12
# 13   Product_1   Region_4   10.15         8.0  2022-01-14
# 15   Product_1   Region_2   46.23        11.0  2022-01-16
# 34   Product_1   Region_9   47.90        11.0  2022-02-04
# 88   Product_1   Region_2   85.46        10.0  2022-03-30
# 140  Product_1   Region_4   28.61         9.0  2022-05-21
# 213  Product_1   Region_6     NaN         8.0  2022-08-02
# 265  Product_1   Region_1  158.05         8.0  2022-09-23
# 312  Product_1   Region_3     NaN        10.0  2022-11-09
# 393  Product_1   Region_6   64.53        10.0  2023-01-29
# 407  Product_1   Region_5   78.94        16.0  2023-02-12
# 467  Product_1  Region_10   88.44         8.0  2023-04-13
# 563  Product_1   Region_1   51.91        16.0  2023-07-18
# 609  Product_1   Region_1   36.67         9.0  2023-09-02
# 711  Product_1   Region_3  268.73         8.0  2023-12-13
# ...

# %%
df['Price'] = df['Price'].fillna(df.groupby('Product')['Price'].transform('mean'))
# TO fill the empty cells by the mean of the group product for each product

# %%
sns.boxplot(data=df, x='Region', y='Price')
# Box plot to see the mean of the mean of the products
# Out:
# <Axes: xlabel='Region', ylabel='Price'>

# %%
sns.boxplot(data=df , x='Product' ,y='Price')
# Box plot to see the mean of the mean of the products
# Out:
# <Axes: xlabel='Product', ylabel='Price'>

# %%
df.sort_values('Product', ascending=True)
# Out:
#        Product    Region       Price  Units Sold   Sale Date
# 140  Product_1  Region_4   28.610000         9.0  2022-05-21
# 213  Product_1  Region_6   76.383125         8.0  2022-08-02
# 711  Product_1  Region_3  268.730000         8.0  2023-12-13
# 34   Product_1  Region_9   47.900000        11.0  2022-02-04
# 964  Product_1  Region_1   71.790000         9.0  2024-08-22
# ..         ...       ...         ...         ...         ...
# 238  Product_9  Region_6   15.780000         NaN  2022-08-27
# 642  Product_9  Region_1   87.160000         6.0  2023-10-05
# 405  Product_9  Region_1   53.610000        14.0  2023-02-10
# 283  Product_9  Region_7  190.140000        11.0  2022-10-11
# 759  Product_9  Region_9    2.490000         9.0  2024-01-30
#
# [797 rows x 5 columns]

# %%
df['Product_ID'] = df['Product'].str[8:9]
#New column product ID which is taken from product

# %%
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date Product_ID
# 2    Product_46   Region_3   20.43        12.0  2022-01-03          4
# 3    Product_36   Region_1   12.77        10.0  2022-01-04          3
# 4    Product_17   Region_6  125.69         6.0  2022-01-05          1
# 5    Product_45   Region_1    8.63        11.0  2022-01-06          4
# 6    Product_31   Region_3   23.73         6.0  2022-01-07          3
# ..          ...        ...     ...         ...         ...        ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15          4
# 993   Product_7   Region_9  128.51        17.0  2024-09-20          7
# 994   Product_1   Region_4   95.24         7.0  2024-09-21          1
# 998   Product_2  Region_10   43.44        15.0  2024-09-25          2
# 999  Product_35   Region_8   56.95         6.0  2024-09-26          3
#
# [797 rows x 6 columns]

# %%
df['Product_ID'] = df['Product'].str[8:10]

# %%
df['Region_ID'] = df ['Region'].str[7:9]

# %%
sns.barplot(x='Region_ID', y='Sales' ,data=df)
#Bar plot for Region_ID and Price
# Out:
# <Axes: xlabel='Region_ID', ylabel='Sales'>

# %%
sns.countplot(data=df, x='Product_ID')
# Out:
# <Axes: xlabel='Product_ID', ylabel='count'>

# %%
df['Sales'] = df['Price'] * df ['Units Sold']
#New column sales which will be a product of price and units sold

# %%
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date Product_ID
# 2    Product_46   Region_3   20.43        12.0  2022-01-03         46  \
# 3    Product_36   Region_1   12.77        10.0  2022-01-04         36
# 4    Product_17   Region_6  125.69         6.0  2022-01-05         17
# 5    Product_45   Region_1    8.63        11.0  2022-01-06         45
# 6    Product_31   Region_3   23.73         6.0  2022-01-07         31
# ..          ...        ...     ...         ...         ...        ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15         42
# 993   Product_7   Region_9  128.51        17.0  2024-09-20          7
# 994   Product_1   Region_4   95.24         7.0  2024-09-21          1
# 998   Product_2  Region_10   43.44        15.0  2024-09-25          2
# 999  Product_35   Region_8   56.95         6.0  2024-09-26         35
#
#     Region_ID    Sales
# 2           3   245.16
# 3           1   127.70
# 4           6   754.14
# 5           1    94.93
# ...

# %%
sns.set(rc={"figure.figsize":(10, 10)})
#Increase the size of the grpah for analysis

# %%
sns.barplot(data = df, x = 'Product_ID', y = 'Sales')
plt.xticks(rotation = 90)
plt.tight_layout()
# To the product sales of every product ID rotated the axis for better view

# %%
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date Product_ID
# 2    Product_46   Region_3   20.43        12.0  2022-01-03         46  \
# 3    Product_36   Region_1   12.77        10.0  2022-01-04         36
# 4    Product_17   Region_6  125.69         6.0  2022-01-05         17
# 5    Product_45   Region_1    8.63        11.0  2022-01-06         45
# 6    Product_31   Region_3   23.73         6.0  2022-01-07         31
# ..          ...        ...     ...         ...         ...        ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15         42
# 993   Product_7   Region_9  128.51        17.0  2024-09-20          7
# 994   Product_1   Region_4   95.24         7.0  2024-09-21          1
# 998   Product_2  Region_10   43.44        15.0  2024-09-25          2
# 999  Product_35   Region_8   56.95         6.0  2024-09-26         35
#
#     Region_ID    Sales
# 2           3   245.16
# 3           1   127.70
# 4           6   754.14
# 5           1    94.93
# ...

# %%
df['Year'] = df ['Sale Date'].str[0:4]
# Creating a column for year used from the sales date

# %%
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date Product_ID
# 2    Product_46   Region_3   20.43        12.0  2022-01-03         46  \
# 3    Product_36   Region_1   12.77        10.0  2022-01-04         36
# 4    Product_17   Region_6  125.69         6.0  2022-01-05         17
# 5    Product_45   Region_1    8.63        11.0  2022-01-06         45
# 6    Product_31   Region_3   23.73         6.0  2022-01-07         31
# ..          ...        ...     ...         ...         ...        ...
# 988  Product_42   Region_9  240.97         NaN  2024-09-15         42
# 993   Product_7   Region_9  128.51        17.0  2024-09-20          7
# 994   Product_1   Region_4   95.24         7.0  2024-09-21          1
# 998   Product_2  Region_10   43.44        15.0  2024-09-25          2
# 999  Product_35   Region_8   56.95         6.0  2024-09-26         35
#
#     Region_ID    Sales  Year
# 2           3   245.16  2022
# 3           1   127.70  2022
# 4           6   754.14  2022
# ...

# %%
sns.barplot(data=df, x='Sales', y='Year', ci= None)
#To see the bar grph values of of sales in every year
# Out:
# /var/folders/yk/m3w26_h527n36v88wgw18khc0000gn/T/ipykernel_85223/4025593874.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Sales', y='Year', ci= None)
# <Axes: xlabel='Sales', ylabel='Year'>

# %%
df['Month'] = df ['Sale Date'].str[5:7]

# %%
sns.barplot(data=df, x='Year', y='Sales' ,hue='Month')
# To see the sales of every year by month
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %% [markdown]
# 1) What conclusions can you draw about sales performance of various products and regions?
#
# - Based on the analysis we made using the data provided, different products performed differently in different regions. Based on the sales and region graph we can conclude that region 2 has the highest sales of all the regions(~1180). Followed by region 8 which has the second highest sales (~ 1160). Since these regions already have customers who are buying our products we can emphasize making the sale we are losing in different regions.
#
# - Region 7 has the lowest sales region followed by region 6. This analysis is based on the sales of the region.
# Product No.49 has the highest sales among all other products in different regions. Followed by product No.20 this is shown in the Product sales in different years (2022-2024).
# Product 3 has the lowest sales of all the products. This could be due to low performance of the product.
#
# -There are months where the sales of the products are performing higher such as months (October-December) sales are pretty consistent in comparsion to other months. This is due could be analyzed due to holidays such as Black friday and other national holidays.
#
# 2) What recommendations do you have for the business?
#
# While overall sales in 2024 have shown an improvement compared to the previous two years, there is still ample room for growth. Several regions, particularly regions 7 and 6, stand out as underperforming areas with untapped sales potential. To address this, we can implement the following strategies to overcome barriers and boost sales:
#
# - Understand the customer base: Recognize that customers in different regions have diverse demands. Conduct thorough market research to gain a comprehensive understanding of our customer base across various regions. This knowledge will enable us to develop tailored marketing strategies. For example, in low-income regions, we can offer discounted products or bundle items at a slightly reduced cost to attract customers.
#
# - Offer long-term payment plans: Initiate partnerships with companies like Klarna to provide long-term payment plans. By allowing customers to make purchases and pay in installments, we can make our products more affordable and accessible, especially in regions where upfront costs may be a barrier.
#
# - Increase brand awareness in underperforming regions: Often, underperforming regions suffer from a lack of brand awareness. Focus on increasing brand visibility and recognition in these areas through targeted advertising campaigns and promotional deals. By highlighting our presence and value proposition, we can attract more customers and generate interest in our offerings.
#
# - Implement a loyalty program: Launching a loyalty program is an effective way to encourage customer retention and repeat purchases. Reward customers for their loyalty with incentives such as points, discounts, or exclusive perks. By creating a sense of value and appreciation, we can foster long-term relationships with our customers.
#
# By implementing these strategies, we can tap into the untapped potential of regions 7 and 6, while also optimizing sales performance across all regions. It is important to continuously monitor and analyze the results, making adjustments as needed to ensure ongoing success in these underperforming areas.
#
#
# 3) Describe your data cleaning approach. How and why did you decide on which cleaning techniques to use?
#
#
# Data cleaning involves the process of eliminating data values that may impede our analysis and findings. It encompasses various steps, including removing duplicates, handling empty cells, dropping irrelevant data, dealing with outliers, and utilizing graphs to draw conclusions. Since the data set had so many missing values we had to take the following steps and approach.
#
# - One crucial step is removing duplicates from the dataset to ensure accurate analysis. Duplicate data entries need to be identified and eliminated in order to obtain the desired outcomes.
#
# - Another important aspect is identifying and handling empty cells. The number of empty cells should be determined, and values that cannot be replaced should be dropped from consideration.
#
# - To ensure accurate analysis, outliers present in the data must be addressed and removed. Outliers have the potential to negatively impact the final results, so their removal is essential.
#
# - Grouping the products and calculating the mean of each group can help replace empty cells with the mean value. This approach contributes to a more comprehensive dataset for analysis.
#
# - Plotting graphs, such as scatter plots, can be utilized to identify any remaining outliers and derive conclusions based on the graphical results.
#
# In my data cleaning process, I followed the conventional approach, incorporating the steps mentioned above.
