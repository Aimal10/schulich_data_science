# %%
import pandas as pd

df= pd.read_csv('messy_data.csv')
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]>

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 1   46  36399.18997  Female     NaN         1
# 2   32  57140.63881  Female       D         2
# 3   60  69554.91903    Male       C         5
# 4   25  53173.80518  Female       D         2

# %%
df.tail()
# Out:
#      Age       Income  Gender Product  Quantity
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df.describe(include='all')
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
df.describe(include=['O'])
# Out:
#         Gender Product
# count      105     100
# unique       2       4
# top     Female       D
# freq        58      28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df.describe(include='all')
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
df[df['Product'].isnull()]
# Out:
#     Age       Income  Gender Product  Quantity
# 1    46  36399.18997  Female     NaN         1
# 34   64  40845.16974  Female     NaN         2
# 45   31  30330.13661    Male     NaN         5
# 86   43  63312.67422  Female     NaN         4
# 94   42  67538.11470    Male     NaN         1

# %%
df['Product']
# Out:
# 0        D
# 1      NaN
# 2        D
# 3        C
# 4        D
#       ...
# 100      D
# 101      A
# 102      B
# 103      B
# 104      C
# Name: Product, Length: 105, dtype: object

# %%
df[df['Income'].isnull()]
# Out:
#      Age  Income  Gender Product  Quantity
# 11    41     NaN  Female       A         5
# 12    53     NaN    Male       B         1
# 28    42     NaN    Male       D         1
# 32    33     NaN    Male       D         2
# 39    38     NaN    Male       A         1
# 42    35     NaN    Male       B         1
# 43    21     NaN    Male       B         2
# 64    59     NaN  Female       B         2
# 66    46     NaN  Female       C         5
# 73    31     NaN  Female       A         4
# 103   21     NaN    Male       B         2

# %%
df[df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Income, Gender, Product, Quantity]
# Index: []

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.iloc[104]
# Out:
# Age                  60
# Income      69554.91903
# Gender             Male
# Product               C
# Quantity              5
# Name: 104, dtype: object

# %%
df.loc[104]
# Out:
# Age                  60
# Income      69554.91903
# Gender             Male
# Product               C
# Quantity              5
# Name: 104, dtype: object

# %%
df[df['Product'] == 'D']
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 2     32  57140.63881  Female       D         2
# 4     25  53173.80518  Female       D         2
# 6     56  36554.97225    Male       D         1
# 8     40  72034.11928    Male       D         2
# 9     28  33141.52498  Female       D         3
# 16    39  57016.92130    Male       D         4
# 19    61  37341.55459    Male       D         5
# 26    39  38269.28261  Female       D         2
# 28    42          NaN    Male       D         1
# 32    33          NaN    Male       D         2
# 35    61  45257.51155  Female       D         5
# 37    54  46567.28726  Female       D         4
# 47    43  42400.35171  Female       D         1
# 49    37  94154.95125  Female       D         5
# 60    57  66300.90535  Female       D         1
# 65    21  28602.81673  Female       D         2
# 74    48  47940.63494    Male       D         2
# 76    25  49318.96017  Female       D         2
# ...

# %%
df[df['Gender'] == 'Female']
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 4     25  53173.80518  Female       D         2
# 5     38  58955.66969  Female       A         2
# 7     36  48320.18269  Female       A         4
# 9     28  33141.52498  Female       D         3
# 10    28  64250.08093  Female       B         4
# 11    41          NaN  Female       A         5
# 14    41  54902.67836  Female       B         4
# 21    55  35516.63492  Female       A         3
# 22    19  52257.33617  Female       B         4
# 24    50  89502.92331  Female       C         2
# 25    29  34623.63667  Female       C         4
# 26    39  38269.28261  Female       D         2
# 27    61  56359.14605  Female       A         3
# 29    44  84308.38974  Female       C         3
# 30    59  74343.80749  Female       A         4
# 33    32  63449.45576  Female       C         5
# ...

# %%
df[df['Gender'] == 'Female']
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 4     25  53173.80518  Female       D         2
# 5     38  58955.66969  Female       A         2
# 7     36  48320.18269  Female       A         4
# 9     28  33141.52498  Female       D         3
# 10    28  64250.08093  Female       B         4
# 11    41          NaN  Female       A         5
# 14    41  54902.67836  Female       B         4
# 21    55  35516.63492  Female       A         3
# 22    19  52257.33617  Female       B         4
# 24    50  89502.92331  Female       C         2
# 25    29  34623.63667  Female       C         4
# 26    39  38269.28261  Female       D         2
# 27    61  56359.14605  Female       A         3
# 29    44  84308.38974  Female       C         3
# 30    59  74343.80749  Female       A         4
# 33    32  63449.45576  Female       C         5
# ...

# %%
df[df['Income'] >50000]
# Out:
#      Age        Income  Gender Product  Quantity
# 0     56   59544.57663  Female       D         3
# 2     32   57140.63881  Female       D         2
# 3     60   69554.91903    Male       C         5
# 4     25   53173.80518  Female       D         2
# 5     38   58955.66969  Female       A         2
# 8     40   72034.11928    Male       D         2
# 10    28   64250.08093  Female       B         4
# 14    41   54902.67836  Female       B         4
# 16    39   57016.92130    Male       D         4
# 17    19   61041.83526    Male       A         5
# 22    19   52257.33617  Female       B         4
# 24    50   89502.92331  Female       C         2
# 27    61   56359.14605  Female       A         3
# 29    44   84308.38974  Female       C         3
# 30    59   74343.80749  Female       A         4
# 31    45   62355.99615    Male       A         2
# 33    32   63449.45576  Female       C         5
# 38    24   64439.61935  Female       B         5
# ...

# %%
df[df['Age'] > 60]
# Out:
#      Age        Income  Gender Product  Quantity
# 19    61   37341.55459    Male       D         5
# 27    61   56359.14605  Female       A         3
# 34    64   40845.16974  Female     NaN         2
# 35    61   45257.51155  Female       D         5
# 51    64   63723.26483  Female       B         3
# 53    61   42293.18763  Female       B         2
# 55    64   28122.24619    Male       C         5
# 69    61   20901.33172    Male       C         5
# 82    62   61845.09207  Female       D         5
# 84    64   33548.71552    Male       D         2
# 88    62   39195.53011    Male       B         4
# 92    62   68734.11049    Male       C         4
# 98   120   34584.33704  Female       C         5
# 99    61  300000.00000    Male       B         4
# 100   61   37341.55459    Male       D         5

# %%
df[df['Product'] == 'D'].describe()
# Out:
#              Age        Income   Quantity
# count  28.000000     26.000000  28.000000
# mean   43.107143  49876.379810   2.642857
# std    13.982368  14148.860233   1.445665
# min    18.000000  28602.816730   1.000000
# 25%    32.750000  38643.331093   1.750000
# 50%    41.500000  48629.797555   2.000000
# 75%    56.250000  57109.709432   4.000000
# max    64.000000  94154.951250   5.000000

# %%
df.set_index('Product').loc['A'].describe()
# Out:
#              Age        Income   Quantity
# count  23.000000     20.000000  23.000000
# mean   41.130435  51745.423588   3.782609
# std    12.721865  15053.572752   1.166055
# min    19.000000  24735.689320   1.000000
# 25%    34.000000  38144.018710   3.000000
# 50%    38.000000  52339.664370   4.000000
# 75%    54.000000  61370.375482   5.000000
# max    61.000000  79618.567950   5.000000

# %%
print(df['Income'].mean(), df['Income'].median())
# Out:
# 52867.86280776596 48760.369705

# %%
print(df['Age'].mean(), df['Age'].median())
# Out:
# 42.076190476190476 41.0

# %%
df['Age'] > 40
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 100     True
# 101     True
# 102    False
# 103    False
# 104     True
# Name: Age, Length: 105, dtype: bool

# %%
print(df['Age'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# Name: Age, Length: 105, dtype: bool

# %%
print(df)
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df2= df.copy()

# %%
df[df['Income'].isnull()]
# Out:
#      Age  Income  Gender Product  Quantity
# 11    41     NaN  Female       A         5
# 12    53     NaN    Male       B         1
# 28    42     NaN    Male       D         1
# 32    33     NaN    Male       D         2
# 39    38     NaN    Male       A         1
# 42    35     NaN    Male       B         1
# 43    21     NaN    Male       B         2
# 64    59     NaN  Female       B         2
# 66    46     NaN  Female       C         5
# 73    31     NaN  Female       A         4
# 103   21     NaN    Male       B         2

# %%
df2['Income'] =df2['Income'].fillna(df2['Income'].mean())

# %%
df2['Income']
# Out:
# 0      59544.576630
# 1      36399.189970
# 2      57140.638810
# 3      69554.919030
# 4      53173.805180
#            ...
# 100    37341.554590
# 101    35516.634920
# 102    53254.050890
# 103    52867.862808
# 104    69554.919030
# Name: Income, Length: 105, dtype: float64

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]>

# %%
df.sort_values(['Age', 'Quantity'])
# Out:
#     Age       Income  Gender Product  Quantity
# 93   18  50984.73737  Female       D         1
# 22   19  52257.33617  Female       B         4
# 17   19  61041.83526    Male       A         5
# 48   19  30350.73969  Female       B         5
# 62   19  43373.50965  Female       A         5
# ..  ...          ...     ...     ...       ...
# 34   64  40845.16974  Female     NaN         2
# 84   64  33548.71552    Male       D         2
# 51   64  63723.26483  Female       B         3
# 55   64  28122.24619    Male       C         5
# 98  120  34584.33704  Female       C         5
#
# [105 rows x 5 columns]

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 1   46  36399.18997  Female     NaN         1
# 2   32  57140.63881  Female       D         2
# 3   60  69554.91903    Male       C         5
# 4   25  53173.80518  Female       D         2

# %%
df ['Total'] = df ['Age'] + df ['Income']

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity        Total
# 0   56  59544.57663  Female       D         3  59600.57663
# 1   46  36399.18997  Female     NaN         1  36445.18997
# 2   32  57140.63881  Female       D         2  57172.63881
# 3   60  69554.91903    Male       C         5  69614.91903
# 4   25  53173.80518  Female       D         2  53198.80518

# %%
df = df.drop(columns= ['Total'])

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 1   46  36399.18997  Female     NaN         1
# 2   32  57140.63881  Female       D         2
# 3   60  69554.91903    Male       C         5
# 4   25  53173.80518  Female       D         2

# %%
df.to_csv('Modified.csv', sep='\t')

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.loc[(df['Age'] >=20) & (df['Income'] <=25000)]
# Out:
#     Age       Income Gender Product  Quantity
# 13   57  24735.68932   Male       A         5
# 69   61  20901.33172   Male       C         5

# %%
df.loc[(df['Gender'] =='Female') | (df['Gender']== 'Male')]
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df[df["Gender"].str.contains("Female")]
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 4     25  53173.80518  Female       D         2
# 5     38  58955.66969  Female       A         2
# 7     36  48320.18269  Female       A         4
# 9     28  33141.52498  Female       D         3
# 10    28  64250.08093  Female       B         4
# 11    41          NaN  Female       A         5
# 14    41  54902.67836  Female       B         4
# 21    55  35516.63492  Female       A         3
# 22    19  52257.33617  Female       B         4
# 24    50  89502.92331  Female       C         2
# 25    29  34623.63667  Female       C         4
# 26    39  38269.28261  Female       D         2
# 27    61  56359.14605  Female       A         3
# 29    44  84308.38974  Female       C         3
# 30    59  74343.80749  Female       A         4
# 33    32  63449.45576  Female       C         5
# ...

# %%
df[df["Gender"].str.contains("Male")]
# Out:
#      Age        Income Gender Product  Quantity
# 3     60   69554.91903   Male       C         5
# 6     56   36554.97225   Male       D         1
# 8     40   72034.11928   Male       D         2
# 12    53           NaN   Male       B         1
# 13    57   24735.68932   Male       A         5
# 15    20   48783.21569   Male       C         4
# 16    39   57016.92130   Male       D         4
# 17    19   61041.83526   Male       A         5
# 18    41   38304.47179   Male       A         4
# 19    61   37341.55459   Male       D         5
# 20    47   47741.99213   Male       A         4
# 23    38   48298.68123   Male       A         5
# 28    42           NaN   Male       D         1
# 31    45   62355.99615   Male       A         2
# 32    33           NaN   Male       D         2
# 39    38           NaN   Male       A         1
# 42    35           NaN   Male       B         1
# 43    21           NaN   Male       B         2
# 44    42   62748.81806   Male       C         1
# ...

# %%
df.describe(include='all')
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
import pandas as pd

df= pd.read_csv('messy_data.csv')
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.groupby(['Income']).sum()
# Out:
#               Age  Gender Product  Quantity
# Income
# 20901.33172    61    Male       C         5
# 24735.68932    57    Male       A         5
# 27763.63630    20  Female       C         1
# 28122.24619    64    Male       C         5
# 28347.74972    41    Male       C         3
# ...           ...     ...     ...       ...
# 79618.56795    35    Male       A         4
# 84308.38974    44  Female       C         3
# 89502.92331    50  Female       C         2
# 94154.95125    37  Female       D         5
# 300000.00000   61    Male       B         4
#
# [90 rows x 4 columns]

# %%
df['count'] = 1 
df.groupby(['Age']). count()['count']
# Out:
# Age
# 18     1
# 19     4
# 20     2
# 21     4
# 23     1
# 24     3
# 25     3
# 26     3
# 27     1
# 28     2
# 29     1
# 31     5
# 32     4
# 33     2
# 34     1
# 35     3
# 36     1
# 37     1
# 38     4
# 39     2
# 40     2
# 41     5
# 42     4
# 43     3
# 44     1
# 45     2
# 46     3
# 47     1
# 48     1
# 50     1
# 51     1
# 52     1
# 53     3
# 54     1
# 55     2
# 56     3
# 57     3
# 58     1
# 59     2
# 60     2
# 61     7
# 62     3
# 64     4
# 120    1
# Name: count, dtype: int64

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity  count
# 0     56  59544.57663  Female       D         3      1
# 1     46  36399.18997  Female     NaN         1      1
# 2     32  57140.63881  Female       D         2      1
# 3     60  69554.91903    Male       C         5      1
# 4     25  53173.80518  Female       D         2      1
# ..   ...          ...     ...     ...       ...    ...
# 100   61  37341.55459    Male       D         5      1
# 101   55  35516.63492  Female       A         3      1
# 102   31  53254.05089    Male       B         2      1
# 103   21          NaN    Male       B         2      1
# 104   60  69554.91903    Male       C         5      1
#
# [105 rows x 6 columns]

# %%
df2= pd.read_csv("customers.csv")

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns={'id':'Customer_id'})

# %%
df2
# Out:
#     Customer_id           cust_name  num_products province  len_relationship
# 0          1001      Johnny Awesome             3       ON                 1  \
# 1          1002          Bob Marley             4       ON                 1
# 2          1004        Taylor Swift             2       AB                 2
# 3          1101          James Dean             3       BC                 3
# 4          1006       Stephen Smith             5       ON                 4
# 5          1014       Delilah Avery             2       AB                 3
# 6          1254        Johnson Cory             1       AB                 4
# 7          1285          Maria Alva             5       ON                 2
# 8          1354        Jessica Fast             4       BC                 5
# 9          1005  Mariah Anita Smith             2       BC                 3
# 10         1008      Robert Optimus             3       MB                10
# ...

# %%
df2.rename({"cust_name": "Customer_name"},inplace=True)

# %%
df2
# Out:
#                       cust_name  num_products province  len_relationship
# Customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.set_index('Customer_id', inplace=True)

# %%
df2
# Out:
#                       cust_name  num_products province  len_relationship
# Customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.head(2)
# Out:
#                   cust_name  num_products province  len_relationship
# Customer_id
# 1001         Johnny Awesome             3       ON                 1  \
# 1002             Bob Marley             4       ON                 1
#
#                 cust_category
# Customer_id
# 1001                   wealth
# 1002         personal_banking

# %%
df2.tail(5)
# Out:
#                       cust_name  num_products province  len_relationship
# Customer_id
# 1354               Jessica Fast             4       BC                 5  \
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# 1475          Stephanie Element             2       ON                 5
#
#                 cust_category
# Customer_id
# 1354         personal_banking
# 1005         personal_banking
# 1008                      hnw
# 1585                   wealth
# 1475         personal_banking

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_name         13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
df2.index
# Out:
# Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#        1475],
#       dtype='int64', name='Customer_id')

# %%
df2
# Out:
#                       cust_name  num_products province  len_relationship
# Customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.rename(columns={"cust_name":"Customer_name"},inplace=True)

# %%
df2 = pd.read_csv("customers.csv")

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2.columns
# Out:
# Index(['id', 'cust_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2.set_index('cust_name')
# Out:
#                       id  num_products province  len_relationship
# cust_name
# Johnny Awesome      1001             3       ON                 1  \
# Bob Marley          1002             4       ON                 1
# Taylor Swift        1004             2       AB                 2
# James Dean          1101             3       BC                 3
# Stephen Smith       1006             5       ON                 4
# Delilah Avery       1014             2       AB                 3
# Johnson Cory        1254             1       AB                 4
# Maria Alva          1285             5       ON                 2
# Jessica Fast        1354             4       BC                 5
# Mariah Anita Smith  1005             2       BC                 3
# Robert Optimus      1008             3       MB                10
# Steven Prime        1585             5       AB                 2
# Stephanie Element   1475             2       ON                 5
#
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2.rename(columns={"cust_name": "customer_name" })
# Out:
#       id       customer_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2.set_index('id')
# Out:
#                cust_name  num_products province  len_relationship
# id
# 1001      Johnny Awesome             3       ON                 1  \
# 1002          Bob Marley             4       ON                 1
# 1004        Taylor Swift             2       AB                 2
# 1101          James Dean             3       BC                 3
# 1006       Stephen Smith             5       ON                 4
# 1014       Delilah Avery             2       AB                 3
# 1254        Johnson Cory             1       AB                 4
# 1285          Maria Alva             5       ON                 2
# 1354        Jessica Fast             4       BC                 5
# 1005  Mariah Anita Smith             2       BC                 3
# 1008      Robert Optimus             3       MB                10
# 1585        Steven Prime             5       AB                 2
# 1475   Stephanie Element             2       ON                 5
#
#          cust_category
# id
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2.axes
# Out:
# [RangeIndex(start=0, stop=13, step=1),
#  Index(['id', 'cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
df2.dtypes
# Out:
# id                   int64
# cust_name           object
# num_products         int64
# province            object
# len_relationship     int64
# cust_category       object
# dtype: object

# %%
df2=df2.rename(columns={'id':'customer_id'})
df2
# Out:
#     customer_id           cust_name  num_products province  len_relationship
# 0          1001      Johnny Awesome             3       ON                 1  \
# 1          1002          Bob Marley             4       ON                 1
# 2          1004        Taylor Swift             2       AB                 2
# 3          1101          James Dean             3       BC                 3
# 4          1006       Stephen Smith             5       ON                 4
# 5          1014       Delilah Avery             2       AB                 3
# 6          1254        Johnson Cory             1       AB                 4
# 7          1285          Maria Alva             5       ON                 2
# 8          1354        Jessica Fast             4       BC                 5
# 9          1005  Mariah Anita Smith             2       BC                 3
# 10         1008      Robert Optimus             3       MB                10
# ...

# %%
df2.set_index('customer_id', inplace=True)

# %%
df2
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.index
# Out:
# Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#        1475],
#       dtype='int64', name='customer_id')

# %%
df2.dtypes
# Out:
# Customers       object
# Num_products     int64
# Province        object
# Relationship     int64
# Category        object
# dtype: object

# %%
df2= pd.read_csv("customers.csv")

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns={'cust_name' : 'customer_name'})

# %%
df2
# Out:
#       id       customer_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns={'id' : 'customer_id'})

# %%
df2
# Out:
#     customer_id       customer_name  num_products province  len_relationship
# 0          1001      Johnny Awesome             3       ON                 1  \
# 1          1002          Bob Marley             4       ON                 1
# 2          1004        Taylor Swift             2       AB                 2
# 3          1101          James Dean             3       BC                 3
# 4          1006       Stephen Smith             5       ON                 4
# 5          1014       Delilah Avery             2       AB                 3
# 6          1254        Johnson Cory             1       AB                 4
# 7          1285          Maria Alva             5       ON                 2
# 8          1354        Jessica Fast             4       BC                 5
# 9          1005  Mariah Anita Smith             2       BC                 3
# 10         1008      Robert Optimus             3       MB                10
# ...

# %%
df2.set_index('customer_id', inplace=True)

# %%
df2
# Out:
#                   customer_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.head(10)
# Out:
#                   customer_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
#
#                 cust_category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1004                      hnw
# ...

# %%
df2.tail(3)
# Out:
#                  customer_name  num_products province  len_relationship
# customer_id
# 1008            Robert Optimus             3       MB                10  \
# 1585              Steven Prime             5       AB                 2
# 1475         Stephanie Element             2       ON                 5
#
#                 cust_category
# customer_id
# 1008                      hnw
# 1585                   wealth
# 1475         personal_banking

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_name     13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
df2.describe()
# Out:
#        num_products  len_relationship
# count     13.000000         13.000000
# mean       3.153846          3.461538
# std        1.344504          2.366974
# min        1.000000          1.000000
# 25%        2.000000          2.000000
# 50%        3.000000          3.000000
# 75%        4.000000          4.000000
# max        5.000000         10.000000

# %%
df2.index
# Out:
# Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#        1475],
#       dtype='int64', name='customer_id')

# %%
df2.columns
# Out:
# Index(['customer_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
df2.axes
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='customer_id'),
#  Index(['customer_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
df2.dtypes
# Out:
# customer_name       object
# num_products         int64
# province            object
# len_relationship     int64
# cust_category       object
# dtype: object

# %%
df2.columns = ['Customers','Num_products','Province','Relationship','Category']

# %%
df2=df2.rename(columns={'Num_products':'Products'})

# %%
df2=df2.rename(columns={'Num_product': 'Product'})

# %%
df2
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1014              Delilah Avery         2       AB             3
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# ...

# %%
df2.sort_index(axis=0, ascending=True)
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1005         Mariah Anita Smith         2       BC             3
# 1006              Stephen Smith         5       ON             4
# 1008             Robert Optimus         3       MB            10
# 1014              Delilah Avery         2       AB             3
# 1101                 James Dean         3       BC             3
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1475          Stephanie Element         2       ON             5
# 1585               Steven Prime         5       AB             2
#
#                      Category
# ...

# %%
df2.Customers
# Out:
# customer_id
# 1001        Johnny Awesome
# 1002            Bob Marley
# 1004          Taylor Swift
# 1101            James Dean
# 1006         Stephen Smith
# 1014         Delilah Avery
# 1254          Johnson Cory
# 1285            Maria Alva
# 1354          Jessica Fast
# 1005    Mariah Anita Smith
# 1008        Robert Optimus
# 1585          Steven Prime
# 1475     Stephanie Element
# Name: Customers, dtype: object

# %%
df2.Province
# Out:
# customer_id
# 1001    ON
# 1002    ON
# 1004    AB
# 1101    BC
# 1006    ON
# 1014    AB
# 1254    AB
# 1285    ON
# 1354    BC
# 1005    BC
# 1008    MB
# 1585    AB
# 1475    ON
# Name: Province, dtype: object

# %%
df2[['Customers','Province']]
# Out:
#                       Customers Province
# customer_id
# 1001             Johnny Awesome       ON
# 1002                 Bob Marley       ON
# 1004               Taylor Swift       AB
# 1101                 James Dean       BC
# 1006              Stephen Smith       ON
# 1014              Delilah Avery       AB
# 1254               Johnson Cory       AB
# 1285                 Maria Alva       ON
# 1354               Jessica Fast       BC
# 1005         Mariah Anita Smith       BC
# 1008             Robert Optimus       MB
# 1585               Steven Prime       AB
# 1475          Stephanie Element       ON

# %%
df2.loc[1002]
# Out:
# Customers             Bob Marley
# Products                       4
# Province                      ON
# Relationship                   1
# Category        personal_banking
# Name: 1002, dtype: object

# %%
df2.loc[[1002,1001]]
# Out:
#                   Customers  Products Province  Relationship          Category
# customer_id
# 1002             Bob Marley         4       ON             1  personal_banking
# 1001         Johnny Awesome         3       ON             1            wealth

# %%
df2.loc[:1101,:'Province']
# Out:
#                   Customers  Products Province
# customer_id
# 1001         Johnny Awesome         3       ON
# 1002             Bob Marley         4       ON
# 1004           Taylor Swift         2       AB
# 1101             James Dean         3       BC

# %%
df2[df2['Products'] == 2]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1004               Taylor Swift         2       AB             2  \
# 1014              Delilah Avery         2       AB             3
# 1005         Mariah Anita Smith         2       BC             3
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1004                      hnw
# 1014         personal_banking
# 1005         personal_banking
# 1475         personal_banking

# %%
df2[df2['Products'] <= 2]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1004               Taylor Swift         2       AB             2  \
# 1014              Delilah Avery         2       AB             3
# 1254               Johnson Cory         1       AB             4
# 1005         Mariah Anita Smith         2       BC             3
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1004                      hnw
# 1014         personal_banking
# 1254                      hnw
# 1005         personal_banking
# 1475         personal_banking

# %%
df2[df2['Products']!= 2]
# Out:
#                   Customers  Products Province  Relationship          Category
# customer_id
# 1001         Johnny Awesome         3       ON             1            wealth
# 1002             Bob Marley         4       ON             1  personal_banking
# 1101             James Dean         3       BC             3            wealth
# 1006          Stephen Smith         5       ON             4               hnw
# 1254           Johnson Cory         1       AB             4               hnw
# 1285             Maria Alva         5       ON             2            wealth
# 1354           Jessica Fast         4       BC             5  personal_banking
# 1008         Robert Optimus         3       MB            10               hnw
# 1585           Steven Prime         5       AB             2            wealth

# %%
df2[(df2['Province']== 'AB') | (df2['Province'] == 'ON')]
# Out:
#                      Customers  Products Province  Relationship
# customer_id
# 1001            Johnny Awesome         3       ON             1  \
# 1002                Bob Marley         4       ON             1
# 1004              Taylor Swift         2       AB             2
# 1006             Stephen Smith         5       ON             4
# 1014             Delilah Avery         2       AB             3
# 1254              Johnson Cory         1       AB             4
# 1285                Maria Alva         5       ON             2
# 1585              Steven Prime         5       AB             2
# 1475         Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1004                      hnw
# 1006                      hnw
# 1014         personal_banking
# 1254                      hnw
# 1285                   wealth
# 1585                   wealth
# ...

# %%
df2
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1014              Delilah Avery         2       AB             3
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# ...

# %%
df2[(df2['Province'] =='MB') | (df2['Province'] == 'BC')| (df2['Province']== 'ON')]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1101                   wealth
# 1006                      hnw
# 1285                   wealth
# 1354         personal_banking
# 1005         personal_banking
# 1008                      hnw
# ...

# %%
df2[(df2['Products']==2) | (df2['Products']==3)]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1014              Delilah Avery         2       AB             3
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1004                      hnw
# 1101                   wealth
# 1014         personal_banking
# 1005         personal_banking
# 1008                      hnw
# 1475         personal_banking

# %%
df2[df2.index.isin([1004,1001])]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1001         Johnny Awesome         3       ON             1   wealth
# 1004           Taylor Swift         2       AB             2      hnw

# %%
df2[df2['Products'].isin(range(2,4))]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1014              Delilah Avery         2       AB             3
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1004                      hnw
# 1101                   wealth
# 1014         personal_banking
# 1005         personal_banking
# 1008                      hnw
# 1475         personal_banking

# %%
df2[df2['Customers'].isin(['Johnny Awesome', 'Robert Optimus'])]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1001         Johnny Awesome         3       ON             1   wealth
# 1008         Robert Optimus         3       MB            10      hnw

# %%
df2[df2['Customers'].isin(['Taylor Swift', 'James Dean'])]
# Out:
#                 Customers  Products Province  Relationship Category
# customer_id
# 1004         Taylor Swift         2       AB             2      hnw
# 1101           James Dean         3       BC             3   wealth

# %%
df2[(df2['Products'] >2) & (df2['Category'].isin(['Wealth', 'hnw']))]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1006          Stephen Smith         5       ON             4      hnw
# 1008         Robert Optimus         3       MB            10      hnw

# %%
df2[(df2['Products'] >2) & (df2['Category'].isin(['wealth' , ' hnw']))]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1001         Johnny Awesome         3       ON             1   wealth
# 1101             James Dean         3       BC             3   wealth
# 1285             Maria Alva         5       ON             2   wealth
# 1585           Steven Prime         5       AB             2   wealth

# %%
df2[(df2['Products'] > 2) & (df2['Category'].isin(['wealth','hnm']))]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1001         Johnny Awesome         3       ON             1   wealth
# 1101             James Dean         3       BC             3   wealth
# 1285             Maria Alva         5       ON             2   wealth
# 1585           Steven Prime         5       AB             2   wealth

# %%
df2[(df2['Products'] >2) & (df2['Category'].isin (['wealth']))]
# Out:
#                   Customers  Products Province  Relationship Category
# customer_id
# 1001         Johnny Awesome         3       ON             1   wealth
# 1101             James Dean         3       BC             3   wealth
# 1285             Maria Alva         5       ON             2   wealth
# 1585           Steven Prime         5       AB             2   wealth

# %%
df2[df2.Customers.str.lower().str.contains('m')]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1285                 Maria Alva         5       ON             2
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1101                   wealth
# 1006                      hnw
# 1285                   wealth
# 1005         personal_banking
# 1008                      hnw
# 1585                   wealth
# ...

# %%
df2[df2.Category.str.lower().str.contains('m')]
# Out:
# Empty DataFrame
# Columns: [Customers, Products, Province, Relationship, Category]
# Index: []

# %%
df3=df2.set_index('Customers').drop(['James Dean'])

# %%
df3
# Out:
#                     Products Province  Relationship          Category
# Customers
# Johnny Awesome             3       ON             1            wealth
# Bob Marley                 4       ON             1  personal_banking
# Taylor Swift               2       AB             2               hnw
# Stephen Smith              5       ON             4               hnw
# Delilah Avery              2       AB             3  personal_banking
# Johnson Cory               1       AB             4               hnw
# Maria Alva                 5       ON             2            wealth
# Jessica Fast               4       BC             5  personal_banking
# Mariah Anita Smith         2       BC             3  personal_banking
# Robert Optimus             3       MB            10               hnw
# Steven Prime               5       AB             2            wealth
# Stephanie Element          2       ON             5  personal_banking

# %%
df4=df2.set_index('Customers').drop(['Maria Alva'])

# %%
df4
# Out:
#                     Products Province  Relationship          Category
# Customers
# Johnny Awesome             3       ON             1            wealth
# Bob Marley                 4       ON             1  personal_banking
# Taylor Swift               2       AB             2               hnw
# James Dean                 3       BC             3            wealth
# Stephen Smith              5       ON             4               hnw
# Delilah Avery              2       AB             3  personal_banking
# Johnson Cory               1       AB             4               hnw
# Jessica Fast               4       BC             5  personal_banking
# Mariah Anita Smith         2       BC             3  personal_banking
# Robert Optimus             3       MB            10               hnw
# Steven Prime               5       AB             2            wealth
# Stephanie Element          2       ON             5  personal_banking

# %%
df2[['Customers', 'Province']]
# Out:
#                       Customers Province
# customer_id
# 1001             Johnny Awesome       ON
# 1002                 Bob Marley       ON
# 1004               Taylor Swift       AB
# 1101                 James Dean       BC
# 1006              Stephen Smith       ON
# 1014              Delilah Avery       AB
# 1254               Johnson Cory       AB
# 1285                 Maria Alva       ON
# 1354               Jessica Fast       BC
# 1005         Mariah Anita Smith       BC
# 1008             Robert Optimus       MB
# 1585               Steven Prime       AB
# 1475          Stephanie Element       ON

# %%
df2.loc[1002]
# Out:
# Customers             Bob Marley
# Products                       4
# Province                      ON
# Relationship                   1
# Category        personal_banking
# Name: 1002, dtype: object

# %%
df2.sort_values('Customers', ascending=True)
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1002                 Bob Marley         4       ON             1  \
# 1014              Delilah Avery         2       AB             3
# 1101                 James Dean         3       BC             3
# 1354               Jessica Fast         4       BC             5
# 1001             Johnny Awesome         3       ON             1
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1475          Stephanie Element         2       ON             5
# 1006              Stephen Smith         5       ON             4
# 1585               Steven Prime         5       AB             2
# 1004               Taylor Swift         2       AB             2
#
#                      Category
# ...

# %%
df2_grouped=df2.groupby('Province')

# %%
df2_grouped.groups
# Out:
# {'AB': [1004, 1014, 1254, 1585], 'BC': [1101, 1354, 1005], 'MB': [1008], 'ON': [1001, 1002, 1006, 1285, 1475]}

# %%
df2_grouped.get_group('ON')
# Out:
#                      Customers  Products Province  Relationship
# customer_id
# 1001            Johnny Awesome         3       ON             1  \
# 1002                Bob Marley         4       ON             1
# 1006             Stephen Smith         5       ON             4
# 1285                Maria Alva         5       ON             2
# 1475         Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1006                      hnw
# 1285                   wealth
# 1475         personal_banking

# %%
df2.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ...

# %%
df2.describe()
# Out:
#         Products  Relationship
# count  13.000000     13.000000
# mean    3.153846      3.461538
# std     1.344504      2.366974
# min     1.000000      1.000000
# 25%     2.000000      2.000000
# 50%     3.000000      3.000000
# 75%     4.000000      4.000000
# max     5.000000     10.000000

# %%
df_trans= pd.read_csv('transactions.csv')

# %%
df_trans.set_index('customer_id', inplace=True)
df_trans
# Out:
#              id txn_type  txn_total
# customer_id
# 1001          1    Debit     165.78
# 1001          2   Credit      42.10
# 1001          4   Credit     103.03
# 1001          5   Credit      56.60
# 1002          6    Debit     214.34
# 1002          7     Cash     115.69
# 1002          8    Debit      21.37
# 1004          9     Cash     227.58
# 1004         10   Credit       5.92
# 1006         11    Debit     225.89
# 1014         12     Cash      67.96
# 1254         13    Debit     235.79
# 1285         14     Cash     160.89
# 1354         15   Credit     377.26
# 1005         16    Debit     276.01
# 1008         17   Credit     190.02
# 1585         18    Debit     320.40
# 1475         19     Cash     328.72
# 1014         20    Debit     449.39
# 1254         21     Cash      15.26
# 1285         22   Credit     393.91
# 1354         23    Debit      94.32
# 1005         24    Debit     403.62
# 1008         25     Cash     242.73
# ...

# %%
df_merged =pd.merge(left=df_trans, right=df2, left_on='customer_id', right_on='customer_id')

# %%
df_merged
# Out:
#              id txn_type  txn_total           Customers  Products Province
# customer_id
# 1001          1    Debit     165.78      Johnny Awesome         3       ON  \
# 1001          2   Credit      42.10      Johnny Awesome         3       ON
# 1001          4   Credit     103.03      Johnny Awesome         3       ON
# 1001          5   Credit      56.60      Johnny Awesome         3       ON
# 1002          6    Debit     214.34          Bob Marley         4       ON
# 1002          7     Cash     115.69          Bob Marley         4       ON
# 1002          8    Debit      21.37          Bob Marley         4       ON
# 1004          9     Cash     227.58        Taylor Swift         2       AB
# 1004         10   Credit       5.92        Taylor Swift         2       AB
# 1006         11    Debit     225.89       Stephen Smith         5       ON
# 1014         12     Cash      67.96       Delilah Avery         2       AB
# ...

# %%
df_merged
# Out:
#              id txn_type  txn_total           Customers  Products Province
# customer_id
# 1001          1    Debit     165.78      Johnny Awesome         3       ON  \
# 1001          2   Credit      42.10      Johnny Awesome         3       ON
# 1001          4   Credit     103.03      Johnny Awesome         3       ON
# 1001          5   Credit      56.60      Johnny Awesome         3       ON
# 1002          6    Debit     214.34          Bob Marley         4       ON
# 1002          7     Cash     115.69          Bob Marley         4       ON
# 1002          8    Debit      21.37          Bob Marley         4       ON
# 1004          9     Cash     227.58        Taylor Swift         2       AB
# 1004         10   Credit       5.92        Taylor Swift         2       AB
# 1006         11    Debit     225.89       Stephen Smith         5       ON
# 1014         12     Cash      67.96       Delilah Avery         2       AB
# ...

# %%
df_merged.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:786, in nanmedian(values, axis, skipna, mask)
#     785 try:
# --> 786     values = values.astype("f8")
#     787 except ValueError as err:
#     788     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'Debit'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[555], line 1
# ----> 1 df_merged.median()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:11623, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, numeric_only, **kwargs)
#   11606 @doc(
#   11607     _num_doc,
#   11608     desc="Return the median of the values over the requested axis.",
# ...

# %%
df_merged.groupby('Customers') ['txn_total'].aggregate(['mean', 'min','max'])
# Out:
#                           mean     min     max
# Customers
# Bob Marley          117.133333   21.37  214.34
# Delilah Avery       233.476667   67.96  449.39
# Jessica Fast        303.290000   94.32  438.29
# Johnny Awesome       91.877500   42.10  165.78
# Johnson Cory        168.753333   15.26  255.21
# Maria Alva          270.466667  160.89  393.91
# Mariah Anita Smith  267.230000  122.06  403.62
# Robert Optimus      199.730000  166.44  242.73
# Stephanie Element   227.466667   87.38  328.72
# Stephen Smith       225.890000  225.89  225.89
# Steven Prime        286.183333  230.24  320.40
# Taylor Swift        116.750000    5.92  227.58

# %%
df_merged.isnull().count()
# Out:
# id              34
# txn_type        34
# txn_total       34
# Customers       34
# Products        34
# Province        34
# Relationship    34
# Category        34
# dtype: int64

# %%
df_merged.isnull().count()
# Out:
# id              34
# txn_type        34
# txn_total       34
# Customers       34
# Products        34
# Province        34
# Relationship    34
# Category        34
# dtype: int64

# %%
df_merged.isna().count()
# Out:
# id              34
# txn_type        34
# txn_total       34
# Customers       34
# Products        34
# Province        34
# Relationship    34
# Category        34
# dtype: int64

# %%
df2 =df2.rename(columns={'customer_id' : 'ABC'})

# %%
df2
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1014              Delilah Avery         2       AB             3
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# ...

# %%
df2=pd.read_csv('customers.csv')

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns=({'cust_name': 'customer_name'}))

# %%
df2.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[578], line 1
# ----> 1 df2.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
df2=pd.read_csv('customers.csv')

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2=df2.rename(columns={'id':'customer_id'})

# %%
df2.set_index('customer_id', inplace=True)

# %%
df2.columns = ['Customers','Num_products','Province','Relationship','Category']

# %%
df2
# Out:
#                       Customers  Num_products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
df2[(df2['Province'] == 'ON') & (df2['Category'] == 'personal_banking')]
# Out:
#                      Customers  Num_products Province  Relationship
# customer_id
# 1002                Bob Marley             4       ON             1  \
# 1475         Stephanie Element             2       ON             5
#
#                      Category
# customer_id
# 1002         personal_banking
# 1475         personal_banking

# %%
df2_grouped=df2.groupby('Province')
df2_grouped.groups
# Out:
# {'AB': [1004, 1014, 1254, 1585], 'BC': [1101, 1354, 1005], 'MB': [1008], 'ON': [1001, 1002, 1006, 1285, 1475]}

# %%
df2_grouped.get_group('ON')
# Out:
#                      Customers  Num_products Province  Relationship
# customer_id
# 1001            Johnny Awesome             3       ON             1  \
# 1002                Bob Marley             4       ON             1
# 1006             Stephen Smith             5       ON             4
# 1285                Maria Alva             5       ON             2
# 1475         Stephanie Element             2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1006                      hnw
# 1285                   wealth
# 1475         personal_banking

# %%
df = pd.read_csv('messy_data.csv')

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df2.rename(columns={'Customers' : 'ABC'})
# Out:
#                             ABC  Num_products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
df2
# Out:
#                       Customers  Num_products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
df2.Customers
# Out:
# customer_id
# 1001        Johnny Awesome
# 1002            Bob Marley
# 1004          Taylor Swift
# 1101            James Dean
# 1006         Stephen Smith
# 1014         Delilah Avery
# 1254          Johnson Cory
# 1285            Maria Alva
# 1354          Jessica Fast
# 1005    Mariah Anita Smith
# 1008        Robert Optimus
# 1585          Steven Prime
# 1475     Stephanie Element
# Name: Customers, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Customers     13 non-null     object
#  1   Num_products  13 non-null     int64
#  2   Province      13 non-null     object
#  3   Relationship  13 non-null     int64
#  4   Category      13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
df2.describe(include='all')
# Out:
#              Customers  Num_products Province  Relationship          Category
# count               13     13.000000       13     13.000000                13
# unique              13           NaN        4           NaN                 3
# top     Johnny Awesome           NaN       ON           NaN  personal_banking
# freq                 1           NaN        5           NaN                 5
# mean               NaN      3.153846      NaN      3.461538               NaN
# std                NaN      1.344504      NaN      2.366974               NaN
# min                NaN      1.000000      NaN      1.000000               NaN
# 25%                NaN      2.000000      NaN      2.000000               NaN
# 50%                NaN      3.000000      NaN      3.000000               NaN
# 75%                NaN      4.000000      NaN      4.000000               NaN
# max                NaN      5.000000      NaN     10.000000               NaN

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[622], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 293 kB 381 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.3 MB 746 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 845 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 229 kB 2.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 7.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 6.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 98 kB 5.1 MB/s eta 0:00:011
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.histplot(df['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(df['Income'])
# Out:
# <Axes: >

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df[df['Income'] ==300000 ]
# Out:
#     Age    Income Gender Product  Quantity
# 99   61  300000.0   Male       B         4

# %%
df.drop(99, axis= 0, inplace=True )

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [104 rows x 5 columns]

# %%
sns.boxplot(df['Income'])
# Out:
# <Axes: >

# %%
sns.histplot(df['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(data= df, x = 'Gender', y='Income')
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
sns.scatterplot(x ='Age' , y='Income', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.lmplot(data= df, x='Age', y='Income', fit_reg= True)

# %%
df.drop(df[df['Age'] ==120]. index, axis = 0 ,inplace=True)

# %%
sns.lmplot(data= df, x='Age', y='Income', fit_reg= True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       98 non-null     int64
#  1   Income    88 non-null     float64
#  2   Gender    98 non-null     object
#  3   Product   93 non-null     object
#  4   Quantity  98 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.6+ KB

# %%
df['Product'] = df['Product'].fillna("Other")

# %%
df.groupby('Gender')['Income'].mean()
# Out:
# Gender
# Female    50205.793962
# Male      50795.175595
# Name: Income, dtype: float64

# %%
df['Income'] = df['Income'].fillna(df['Income'].mean())
